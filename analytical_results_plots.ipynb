# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams.update({'font.size': 18,
                     'font.weight': 'bold'
                     })

# %%
column_mapping = {
    '0': 't',
    '1': 'msd_a',
    '2': 'msd_b',
    '3': 'msd_total',
    '4': 'shorttime_limit1',
    '5': 'shorttime_limit2',
    '6': 'shorttime_limit3',
    '7': 'longtime_limit',
#    '7': 'precision'
}
df1_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L2.csv', names=column_mapping.keys()) #,usecols=column_mapping.keys())
df2_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L33.csv', names=column_mapping.keys())
df3_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L4.csv', names=column_mapping.keys())
# Rename columns using the mapping
df1 = df1_.rename(columns=column_mapping)
df2 = df2_.rename(columns=column_mapping)
df3 = df3_.rename(columns=column_mapping)

df = pd.concat([df1, df2, df3], ignore_index=True)
df.head()
# Out:
#        t  msd_a      msd_b  msd_total  shorttime_limit1  shorttime_limit2  \
# 0  0.001   0.04   0.021997   0.039982             0.004             0.002
# 1  0.201   8.04   4.300879   7.359152             0.804             0.402
# 2  0.401  16.04   8.340885  13.496598             1.604             0.802
# 3  0.601  24.04  12.144865  18.666528             2.404             1.202
# 4  0.801  32.04  15.717470  23.044325             3.204             1.602
#
#    shorttime_limit3  longtime_limit
# 0          0.003636             NaN
# 1          0.730909             NaN
# 2          1.458182             NaN
# 3          2.185455             NaN
# 4          2.912727             NaN

# %%
x = df['t']

# Extract other columns for y-axis
y_columns = ['msd_b', 'msd_total']

# Plot all other columns against 't'
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], label=column)
plt.plot(x, df['shorttime_limit1'], linestyle='--', color='black')

# Add labels and legend
plt.xlabel('t')
plt.ylabel('Value')
plt.xscale('log')
plt.yscale('log')
plt.title('Plot of t column on x-axis and other columns on y-axis')
plt.legend()
plt.show()

# %%
def import_analytical_num_df(csv_path):
    num_column_mapping = {
        '0': 't',
        '1': 'num_a',
        '2': 'num_b',
        '3': 'num_total',
        '4': 'shortN1',
        '5': 'shortN2',
        '6': 'shortN12',
        '7': 'LongLimN1',
        '8': 'LongLimN2',
        '9': 'LongLimN12',
    }
    df1_ = pd.read_csv(f'{csv_path}.csv', names=num_column_mapping.keys()) #,usecols=column_mapping.keys())
    #df2_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L33.csv', names=column_mapping.keys())
    #df3_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L4.csv', names=column_mapping.keys())
    # Rename columns using the mapping
    df1 = df1_.rename(columns=num_column_mapping)
    #df2 = df2_.rename(columns=column_mapping)
    #df3 = df3_.rename(columns=column_mapping)

    #df = pd.concat([df1, df2, df3], ignore_index=True)
    df1.head()
    return df1

def plot_analytical_population(df1, ylim_left=1, ylim_right=2000, savepath=None):
    x = df1['t']

    # Extract other columns for y-axis
    y_columns = ['num_a', 'num_b', 'num_total']
    y_label = ['$N_A$','$N_B$','$N_{overall}$']
    colors = ['red', 'blue','orange']

    # Plot all other columns against 't'
    plt.figure(figsize=(10, 6))
    for column, label, color in zip(y_columns, y_label, colors):
        plt.plot(x, df1[column], label=label, color=color, linewidth=2)
    plt.plot(x, df1['shortN1'], linestyle='--', color='black')
    plt.plot(x, df1['shortN2'], linestyle='--', color='black')
    plt.plot(x, df1['shortN12'], linestyle='--', color='black')
    plt.plot(x, df1['LongLimN1'], linestyle='--', color='black')
    plt.plot(x, df1['LongLimN2'], linestyle='--', color='black')
    plt.plot(x, df1['LongLimN12'], linestyle='--', color='black')


    # Add labels and legend
    plt.xlabel('$t,(ns)$')
    plt.ylabel('$N(t)$')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(0.001,1000)
    plt.ylim(ylim_left,ylim_right)
    #plt.title('Population over Time')
    #plt.legend()
    if savepath is not None:
      plt.savefig(f'{savepath}.png')
    plt.show()

# %%
def import_analytical_msd_df(csv_path):

    column_mapping = {
        '0': 't',
        '1': 'MSD_A',
        '2': 'MSD_B',
        '3': 'MSD_overall',
        '4': 'shortLim',
        '5': 'shortLim2',
        '6': 'MSDLongLim',
    #    '7': 'precision'
    }
    df1_ = pd.read_csv(f'{csv_path}.csv', names=column_mapping.keys()) #,usecols=column_mapping.keys())
    #df2_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L33.csv', names=column_mapping.keys())
    #df3_ = pd.read_csv(f'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/Fig5L4.csv', names=column_mapping.keys())
    # Rename columns using the mapping
    df1 = df1_.rename(columns=column_mapping)
    #df2 = df2_.rename(columns=column_mapping)
    #df3 = df3_.rename(columns=column_mapping)

    #df = pd.concat([df1, df2, df3], ignore_index=True)
    df1.head()
    return df1

def plot_analytical_msd(df1, savepath):
    x = df1['t']

    # Extract other columns for y-axis
    y_columns = ['MSD_A', 'MSD_B', 'MSD_overall']
    y_label = ['$MSD_A$','$MSD_B$','$MSD_{overall}$']
    colors = ['red', 'blue','orange']

    # Plot all other columns against 't'
    plt.figure(figsize=(10, 6))
    for column, label, color in zip(y_columns, y_label, colors):
        plt.plot(x, df1[column], label=label, color=color, linewidth=2)
    plt.plot(x, df1['shortLim'], linestyle='--', color='black')
    plt.plot(x, df1['shortLim2'], linestyle='--', color='black')
    plt.plot(x, df1['MSDLongLim'], linestyle='--', color='black')

    # Add labels and legend
    plt.xlabel('$t, ns$', fontweight='bold', fontsize=20)
    plt.ylabel('$\\langle r^2(t) \\rangle, \\mu m^2$', fontweight='bold', fontsize=20)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(0.001,1000)
    #plt.title('Mean Square Displacement over Time')
    #plt.legend()
    plt.savefig(f'{savepath}.png')
    plt.show()

# %%
num_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig6'
msd_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig6'

df_msd = import_analytical_msd_df(msd_csv_path)
df_num = import_analytical_num_df(num_csv_path)

plot_analytical_msd(df_msd, msd_csv_path)
plot_analytical_population(df_num, ylim_left=1, ylim_right=2000, savepath=num_csv_path)

# %%
num_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig7'
msd_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig7'

df_msd = import_analytical_msd_df(msd_csv_path)
df_num = import_analytical_num_df(num_csv_path)

plot_analytical_msd(df_msd, msd_csv_path)
plot_analytical_population(df_num, ylim_left=1, ylim_right=1500, savepath=num_csv_path)

# %%
num_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig8'
msd_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig8'

df_msd = import_analytical_msd_df(msd_csv_path)
df_num = import_analytical_num_df(num_csv_path)

plot_analytical_msd(df_msd, msd_csv_path)
plot_analytical_population(df_num, ylim_left=1000, ylim_right=9000000, savepath=num_csv_path)

# %%
num_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig9'
msd_csv_path = '/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig9'

df_msd = import_analytical_msd_df(msd_csv_path)
df_num = import_analytical_num_df(num_csv_path)

plot_analytical_msd(df_msd, msd_csv_path)
plot_analytical_population(df_num, ylim_left=1000, ylim_right=9000000, savepath=num_csv_path)

# %%
csvpath_msd_Fig6 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig6'
csvpath_msd_Fig7 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig7'
csvpath_msd_Fig8 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig8'
csvpath_msd_Fig9 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig9'

analytical_msd_df_Fig6 = import_analytical_msd_df(csvpath_msd_Fig6)
analytical_msd_df_Fig7 = import_analytical_msd_df(csvpath_msd_Fig7)
analytical_msd_df_Fig8 = import_analytical_msd_df(csvpath_msd_Fig8)
analytical_msd_df_Fig9 = import_analytical_msd_df(csvpath_msd_Fig9)



fig, axes = plt.subplots(2, 2, figsize=(16, 14)) # Adjust figsize as needed

# Data for each subplot
dataframes = [analytical_msd_df_Fig6, analytical_msd_df_Fig7,
              analytical_msd_df_Fig8, analytical_msd_df_Fig9]


subtitles = ["(a)", "(b)",
             "(c)", "(d)"]

# Iterate through subplots and dataframes
for i, (ax, df, subtitle) in enumerate(zip(axes.flatten(), dataframes, subtitles)):
    x = df['t']
    y_columns = ['MSD_A', 'MSD_B', 'MSD_overall']
    y_label = ['$MSD_A$','$MSD_B$','$MSD_{overall}$']
    colors = ['red', 'blue','orange']

    for column, label, color in zip(y_columns, y_label, colors):
        ax.plot(x, df[column], label=label, color=color)
    ax.plot(x, df['shortLim'], linestyle='--', color='black')
    ax.plot(x, df['shortLim2'], linestyle='--', color='black')
    ax.plot(x, df['MSDLongLim'], linestyle='--', color='black')
    ax.set_xscale('log')
    ax.set_yscale('log')

    if i==0 or i==2:
        ax.set_ylabel('$\\langle \\mathrm{r}^2(t) \\rangle, \\mu m^2$', fontweight='bold', fontsize=20)
    if i==2 or i==3:
        ax.set_xlabel('$t, ns$', fontweight='bold', fontsize=20)
    ax.set_xlim(0.001,1000)
    #ax.set_subtitle(subtitle, fontweight='bold')
    #ax.legend()
    ax.text(0.5, 0.9, subtitle, ha='center', transform=ax.transAxes, fontweight='bold', fontsize=20)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("combined_analyt_plot.eps", format='eps')
#plt.tight_layout()
plt.show()

# %%
csvpath_popul_Fig7 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig7'
csvpath_popul_Fig8 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig8'

analytical_popul_df_Fig7 = import_analytical_num_df(csvpath_popul_Fig7)
analytical_popul_df_Fig8 = import_analytical_num_df(csvpath_popul_Fig8)

fig, axes = plt.subplots(2, 1, figsize=(10, 16))

dataframes = [analytical_popul_df_Fig7, analytical_popul_df_Fig8]

subtitles = ["(a)", "(b)"]
ylim_arrs = [(1,1000),(1000,9_000_000)]

for i, (ax, df, subtitle) in enumerate(zip(axes.flatten(), dataframes, subtitles)):
    x = df['t']
    y_columns = ['num_a', 'num_b', 'num_total']
    y_label = ['$N_A$','$N_B$','$N_{overall}$']
    colors = ['red', 'blue','orange']

    for ylim_arr, column, label, color in zip(ylim_arrs, y_columns, y_label, colors):
        ax.plot(x, df[column], label=label, color=color)
        ax.set_ylim(ylim_arr)
        ax.set_xscale('log')
        ax.set_yscale('log')
    ax.plot(x, df['shortN1'], linestyle='--', color='black')
    ax.plot(x, df['shortN2'], linestyle='--', color='black')
    ax.plot(x, df['shortN12'], linestyle='--', color='black')
    ax.plot(x, df['LongLimN1'], linestyle='--', color='black')
    ax.plot(x, df['LongLimN2'], linestyle='--', color='black')
    ax.plot(x, df['LongLimN12'], linestyle='--', color='black')


    #if i==0 or i==2:
    ax.set_ylabel('$N(t)$', fontweight='bold', fontsize=20)
    #if i==2 or i==3:
    ax.set_xlabel('$t, ns$', fontweight='bold', fontsize=20)
    #ax.set_subtitle(subtitle, fontweight='bold')
    ax.set_xlim(0.001,1000)

    ax.legend()
    ax.text(0.5, 0.9, subtitle, ha='right', transform=ax.transAxes, fontweight='bold', fontsize=20)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("combined_analyt_plot.eps", format='eps')
#plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
csvpath_popul_Fig7 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig7'
csvpath_popul_Fig8 = r'/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/popul_Fig8'

analytical_popul_df_Fig7 = import_analytical_num_df(csvpath_popul_Fig7)
analytical_popul_df_Fig8 = import_analytical_num_df(csvpath_popul_Fig8)

fig, axes = plt.subplots(2, 1, figsize=(10, 16))

dataframes = [analytical_popul_df_Fig7, analytical_popul_df_Fig8]
subtitles = ["(a)", "(b)"]
ylim_arrs = [(1, 2000), (1000, 9_000_000)]
colors = ['red', 'blue', 'orange']
labels = ['$N_A$', '$N_B$', '$N_{overall}$']
columns = ['num_a', 'num_b', 'num_total']

for i, (ax, df, subtitle, ylim) in enumerate(zip(axes, dataframes, subtitles, ylim_arrs)):
    for column, label, color in zip(columns, labels, colors):
        ax.loglog(df['t'], df[column], label=label, color=color)  # Use loglog directly
        ax.set_ylim(ylim)

    # Plot dashed lines
    dashed_columns = ['shortN1', 'shortN2', 'shortN12', 'LongLimN1', 'LongLimN2', 'LongLimN12']
    for col in dashed_columns:
        ax.loglog(df['t'], df[col], linestyle='--', color='black')

    ax.set_ylabel('$N(t)$', fontweight='bold', fontsize=20)
    ax.set_xlabel('$t, ns$', fontweight='bold', fontsize=20)
    ax.set_xlim(0.001, 1000)
    #ax.legend(fontsize=14)  # Adjust legend font size if needed
    ax.text(0.45, 0.95, subtitle, ha='right', transform=ax.transAxes, fontweight='bold', fontsize=20)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig("combined_analyt_plot.eps", format='eps')
plt.show()

# %%
# Load the four existing plots
plot1 = plt.imread("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig6.png")
plot2 = plt.imread("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig7.png")
plot3 = plt.imread("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig8.png")
plot4 = plt.imread("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig9.png")

# Create a figure and axes with a 2x2 grid layout
fig, axs = plt.subplots(2, 2)

# Plot the images on the subplots
axs[0, 0].imshow(plot1)
axs[0, 1].imshow(plot2)
axs[1, 0].imshow(plot3)
axs[1, 1].imshow(plot4)

# Remove the axis ticks and labels
for ax in axs.flat:
    ax.axis('off')
plt.tight_layout(pad=-2,h_pad=-7)
plt.savefig("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/combined_msd_plots.eps", format='eps')
plt.savefig("/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/combined_msd_plots.png")
# Show the combined plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Load existing PNG files
plot1 = r"/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig6.png"
plot2 = r"/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig7.png"
plot3 = r"/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig8.png"
plot4 = r"/content/drive/MyDrive/Skoltech_Researches/Exciton_Semiconductors/analytical_data/msd_Fig9.png"
image_paths = [plot1, plot2, plot3, plot4]

# Create a grid for the subplots with tighter spacing
fig, axs = plt.subplots(2, 2, figsize=(8, 6), tight_layout=True)

# Iterate through the image paths and plot them in the grid
for i, ax in enumerate(axs.flat):
    image = plt.imread(image_paths[i])
    ax.imshow(image)
    ax.axis('off')  # Turn off axis ticks and labels

# Save the combined plot as EPS
plt.savefig("combined_plots.eps", format='eps')

# Show the combined plot
plt.show()

# %% [markdown]
# ## Correspondence of Analytical and Simulation

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm
from multiprocessing import Pool

# %%
steps = np.array([[0, 7/5], [0, -7/5], [7/5, 0], [-7/5, 0]])

def simulate_trajectory(args):
    t_cutoff, tau_A, tau_B, dt, lambda_A, lambda_B, alpha = args
    num_steps = int(t_cutoff / dt) + 1
    positions = np.zeros((num_steps, 2), dtype=np.int64)
    states = np.empty(num_steps, dtype=np.str_)
    states[0] = 'A'
    t = 0

    for i in range(1, num_steps):
        if np.random.rand() < (alpha if states[i - 1] == 'A' else 0) * dt:
            break

        if states[i - 1] == 'A' and np.random.rand() < lambda_A * dt:
            states[i] = 'B'
        elif states[i - 1] == 'B' and np.random.rand() < lambda_B * dt:
            states[i] = 'A'
        else:
            states[i] = states[i - 1]

        step_size = tau_A if states[i] == 'A' else tau_B
        step = steps[np.random.randint(4)] / step_size
        positions[i] = positions[i - 1] + np.round(step).astype(np.int64)
        t += dt

    return {'t': np.arange(t, step=dt), 'x': positions[:, 0], 'y': positions[:, 1], 'state': states}

def run_simulation_multi_parallel(t_cutoff, tau_A, tau_B, dt, lambda_A, lambda_B, alpha, num_trajectories):
    # Create an iterable of arguments for simulate_trajectory
    args_list = [(t_cutoff, tau_A, tau_B, dt, lambda_A, lambda_B, alpha)] * num_trajectories

    # Use multiprocessing Pool to parallelize the simulation
    with Pool() as pool:
        trajectories = list(tqdm.tqdm(pool.imap(simulate_trajectory, args_list), total=num_trajectories))

    return trajectories

# %%
def plot_analytical_msd(df1, savepath):
    x = df1['t']

    # Extract other columns for y-axis
    y_columns = ['MSD_A', 'MSD_B', 'MSD_overall']
    y_label = ['$MSD_A$','$MSD_B$','$MSD_{overall}$']
    colors = ['red', 'blue','orange']

    # Plot all other columns against 't'
    plt.figure(figsize=(10, 6))
    for column, label, color in zip(y_columns, y_label, colors):
        plt.plot(x, df1[column], label=label, color=color)
    #plt.plot(x, 0.25*df1['shorttime_limit1'], linestyle='--', color='black')

    # Add labels and legend
    plt.xlabel('$t, ns$', fontweight='bold')
    plt.ylabel('$\\langle r^2(t) \\rangle, \\mu m^2$', fontweight='bold')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(0.001,1000)
    plt.title('Mean Square Displacement over Time')
    plt.legend()
    plt.savefig(f'{savepath}.png')
    plt.show()

# %%
def get_analytical_parameter_corresp(D_A, D_B, lambda_A, lambda_B, alpha, lattice_constant=1.0):
    tau_A = lattice_constant**2/(2*D_A)
    tau_B = lattice_constant**2/(2*D_B)
    sim_lambda_A = lambda_A
    sim_lambda_B = lambda_B
    sim_alpha = alpha
    return tau_A, tau_B, sim_lambda_A, sim_lambda_B, sim_alpha

# %%
def analyze_trajectories(trajectories, t_cutoff, tau_A, tau_B, dt, lambda_A, lambda_B, alpha, analytical_msd_df):
    max_time_steps = int(t_cutoff / dt) + 1
    msd_data = {'A': np.zeros(max_time_steps), 'B': np.zeros(max_time_steps), 'overall': np.zeros(max_time_steps)}
    population_data = {'A': np.zeros(max_time_steps), 'B': np.zeros(max_time_steps), 'overall': np.zeros(max_time_steps)}


    for traj in trajectories:
        initial_pos = np.array([traj['x'][0], traj['y'][0]])
        for t, (x, y, state) in enumerate(zip(traj['x'], traj['y'], traj['state'])):
            displacement = (x - initial_pos[0])**2 + (y - initial_pos[1])**2
            if state:  # Check if state is not empty
                msd_data[state][t] += displacement
                msd_data['overall'][t] += displacement
                population_data[state][t] += 1
                population_data['overall'][t] += 1

    time_steps = np.arange(max_time_steps) * dt
    plt.figure(figsize=(10, 6))
    x = analytical_msd_df['t']
    y_columns = ['MSD_A', 'MSD_B', 'MSD_overall']
    y_label = ['$MSD_A$','$MSD_B$','$MSD_{overall}$']
    colors = ['red', 'blue','orange']
    markers = ['o','^', '*']
    for column, label, color in zip(y_columns, y_label, colors):
        plt.plot(x, df1[column], label=label, color=color)

    for state, color,marker in zip(['A', 'B', 'overall'], colors, markers):
        msd_data[state] /= population_data[state]
        plt.plot(time_steps[1:], msd_data[state][1:], label=f'MSD: {state}', marker=marker, color=color)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(0.001,1000)
    plt.xlim(min(time_steps), max(time_steps))
    plt.xlabel('Time')
    plt.ylabel('MSD')
    plt.title(f"Mean Square Displacement over Time, $\\alpha$={alpha}, $\\lambda_A$={lambda_A}, $\\lambda_B$={lambda_B}, $\\tau_A$={tau_A}, $\\tau_B$={tau_B}")
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 6))
    colors = ['red', 'blue','orange']
    for state, color, marker in zip(['A', 'B', 'overall'], colors, markers):
        plt.plot(time_steps[1:], population_data[state][1:], label=f'Population: {state}', marker=marker, color=color)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(0.001,1000)
    plt.xlim(min(time_steps), max(time_steps))
    plt.xlabel('Time')
    plt.ylabel('Population')
    plt.title(f"Population over Time, $\\alpha$={alpha}, $\\lambda_A$={lambda_A}, $\\lambda_B$={lambda_B}, $\\tau_A$={tau_A}, $\\tau_B$={tau_B}")
    plt.legend()
    plt.show()

# %%
num_trajectories = 1000
dt = 0.001
t_cutoff = 100.0
lambda_A = 1
lambda_B = 0.1
alpha = 0.0
D_A, D_B =  0.5, 0.01
tau_A, tau_B, sim_lambda_A, sim_lambda_B, sim_alpha = get_analytical_parameter_corresp(D_A, D_B, lambda_A, lambda_B, alpha, lattice_constant=7/5)
#print(f'tau_A={tau_A}, tau_B={tau_B}')
trajectories = run_simulation_multi_parallel(t_cutoff, tau_A, tau_B, dt, sim_lambda_A, sim_lambda_B, sim_alpha, num_trajectories)
# Out:
# 100%|██████████| 1000/1000 [27:21<00:00,  1.64s/it]

# %%
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.1/324.1 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
